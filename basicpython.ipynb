# %%
x = 3 + 4j
print(type(x))
# Out:
# <class 'complex'>

# %%
a = "Hello"
print(a)
# Out:
# Hello

# %%
for x in "banana": #loop inside string
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
a = "I am Rashmi Dahal"
print(a[5])
print(len(a))
# Out:
# R
# 17

# %%
txt = 'hey its me rashmi, I am Rashmi Dahal'
print('Rashmi Dahal' in txt)
# Out:
# True

# %%
txt = 'Our country is Nepal And its very beautiful'
if 'Nepal' in txt:
    print('Yes, "Nepal" is present in txt')
# Out:
# Yes, "Nepal" is present in txt

# %%
txt = "Best thing in life are free"
if 'Expensive'not in txt:
    print("'Expensive', is not present in txt")
# Out:
# 'Expensive', is not present in txt

# %%
a = "Hello i am rashmi dahal"
print(a[:10])
# Out:
# Hello i am

# %%
name = "Rashmi Dahal"
print(name[-2])
# Out:
# a

# %%
greeting = "Hello, Rashmi Dahal"
print(greeting[-5:-2])# -5 = D and -2 = h
# Out:
# Dah

# %%
x = "Welcome"
print(x[-5:-1])
# Out:
# lcom

# %%
#convert all lowercase to uppercase letter
name = "Rashmi Dahal"
print(name.upper())
# Out:
# RASHMI DAHAL

# %%
#convert all uppercase to lowercase letter
name = "Rashmi Dahal"
print(name.lower())
# Out:
# rashmi dahal

# %%
a = "Hello World ! "
print(a.strip()) #strip() method removes any white spaces from begining or end
# Out:
# Hello World !

# %%
a = "Rashmi DAhal"
print(a.split())
# Out:
# ['Rashmi', 'DAhal']

# %%
a = "Dahal Rashmi"
print(a.replace("Dahal","Rashmi"))
# Out:
# Rashmi Rashmi

# %%
a = "Rashmi,Dahal"
print(a.split(","))
print(a.count("a"))
print(a.endswith("a"))
print(a.find("a"))
print(a.islower())
# Out:
# ['Rashmi', 'Dahal']
# 3
# False
# 1
# False

# %%
# String concatination
a = "Rashmi"
b = "Dahal"
print(a+b)
# Out:
# RashmiDahal

# %%
a = "Hello"
b = "World!"
print(a+" "+b) #Adding space between two string
# Out:
# Hello World!

# %%
age = 42
name = "Rashmi"
sname = "Dahal"
print("My name is "+name+" "+sname)
print(f"My father's age is {age}.")
# Out:
# My name is Rashmi Dahal
# My father's age is 42.

# %%
print(f"price of 20 liter petrol is {202*20}")
# Out:
# price of 20 liter petrol is 4040

# %%
print('it\'s me Rashmi') #inside '' single quote it we want another ' put \' like this
# Out:
# it's me Rashmi

# %%
#Write a Python program to print: "Hello, Python!"
print("Hello,python!")
# Out:
# Hello,python!

# %%
#Take a string input from user and print its length.
name = input("Enter your name: ")
print(name)
print(len(name))
# Out:
# Rashmi
# 6

# %%
#Write a program to convert a string into uppercase.
yourname = input("Enter your name: ")
print(yourname.upper())
# Out:
# RASHMI

# %%
#Write a program to convert a string into lowercase.
student = input("Enter your name:")
print(student.lower())
# Out:
# dahal

# %%
#Write a program to count how many times the letter 'a' appears in a string.
yourvillage = input("Enter your village: ")
print(yourvillage)
print(yourvillage.count('a'))
num = yourvillage.count('j') or yourvillage.count('J')
print(f"There are {num} of j in your village.")
# Out:
# Jhapa
# 2
# There are 1 of j in your village.

# %%
#Write a Python program to reverse a string.
name = input('Enter your name:')
print(name[::-1])
# Out:
# imhsaR

# %%
name = "Rashmi"#checking palindrome [ by ant = tnt i.e not palindrome
a = print(name[::-1])
b = print(name[:])
if a == b:
    print('name is palindrome')
else:
    print('name is not palindrome')
# Out:
# imhsaR
# Rashmi
# name is palindrome

# %%
name = input("enter a name: ")
if num == name[::-1]:
    print(name+'is palindrome number')
else:
    print(name+' is not palindrome number')
# Out:
# rashmi is not palindrome number

# %%
sentence = "Ram is a good boy"#Replace a word in a string with another word.
#(Example: replace "bad" with "good")
print(sentence.replace("good","bad"))
# Out:
# Ram is a bad boy

# %%
#First and Last Character
# Print the first and last character of a string.
sentence = "Hey! it\'s me Rashmi Dahal"
print('first character is', sentence[0]+" "+'and last character is',sentence[-1])
# Out:
# first character is H and last character is l

# %%
sentence = "  Ram is a good boy!  "
print(sentence.strip())
# Out:
# Ram is a good boy!

# %%
sentence = "My name is Rashmi Dahal"
a = sentence.count('a' or 'b' or 'e' or 'i' or 'o' or 'u' or 'A' or 'E' or 'I' or 'O' or 'U' or 'A')
print(a)
# Out:
# 4

# %%
#Convert first letter of string into uppercase.
sentence = "my name is Rashmi Dahal"
print(sentence[0].upper())
# Out:
# M

# %%
'''Write a program that takes 3 numbers and:
finds the maximum using only operators (no built-in functions)
checks if all are equal using logical operators'''
a = int(input("Enter first number:"))
b = int(input("Enter second number:"))
c = int(input("Enter third number:"))
if a == b and a == c:
    print("The numbers are equal")
elif a>b and a>c:
    print(f'{a} is grater than {b} and {c}')
elif b>c and b>a:
    print(f'{b} is grater than {a} and {c}')
else:
    print(f'{c} is grater than {a} and {b}')
# Out:
# 20 is grater than 10 and 5

# %%
'''Create a login system:
username = "admin"
password = "1234"
Use logical operators to validate input.'''
username = input("Enter username: ")
password = int(input("Enter password: "))
if username == "admin" and password == 1234:
    print("Login successful")
else:
    print("             Warning                ")
    print("Enter valid username and password !!")
# Out:
# Login successful

# %%
#Write a program to toggle a boolean value using not
value = input("Enter true or False")
value = not value
print('Toggle value is',value)
# Out:
# Toggle value is False

# %%
#Use bitwise operators (&, |) to compare two numbers.
num1 = int(input('Enter first number: '))
num2 = int(input('Enter second number: '))
print('Bitwise OR',num1|num2)
print('Bitwise AND',num1&num2)
# Out:
# Bitwise OR 3
# Bitwise AND 2

# %%
"""Take a number and check:
divisible by 2 → print "Two"
divisible by 3 → print "Three"
divisible by both → print "TwoThree"""

number = int(input("Enter a number: "))
if number % 2 == 0 and number % 3 == 0:
    print("The number is divisible by 2 and 3")
elif number % 3 == 0:
    print("The number is divisible by 3")
elif number % 2 == 0:
    print("Number divisible by 2 ")
# Out:
# The number is divisible by 3

# %%
#Check leap year
days = int(input("Enter number of days in this year:"))
if days == 366:
    print("This is leap year")
else:
    print("Not a leap year")
# Out:
# This is leap year

# %%
name = "Rashmi"
if 'a' or 'e' or 'i' or 'o' or 'u' or 'A' or 'E' or 'I' or 'O' or 'U' or 'A' in name:
    print("name contains vowel letters")
# Out:
# name contains vowel letters

# %%
#list practice
fruits = ["apple","banana","orange","strawberry","peach","grapefruit"]
print(fruits[0:3])
# Out:
# ['apple', 'banana', 'orange']

# %%
name = "Rashmi"
print(name[0])
print(name[1:3])
# Out:
# R
# as

# %%
fruits = ["apple","banana","orange","strawberry","peach","grapefruit"]
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'strawberry', 'peach', 'grapefruit']

# %%
fruits = fruits = ["apple","banana","orange","banana","apple","strawberry","peach","grapefruit"]
print(fruits)# List allows duplicate values
# Out:
# ['apple', 'banana', 'orange', 'banana', 'apple', 'strawberry', 'peach', 'grapefruit']

# %%
fruits = ["apple","banana","orange","strawberry","peach","grapefruit"]
print(len(fruits))
# Out:
# 6

# %%
rashmi = ["Dahal","Nuwakot",23,9803541509]
print(rashmi)#List can be of any datatype
print(type(rashmi))
# Out:
# ['Dahal', 'Nuwakot', 23, 9803541509]
# <class 'list'>

# %%
rashmi = list(("Rashmi","Dahal""Nuwakot",33,9803541509))
#We can also create list using double bracket (( with list
print(rashmi)
# Out:
# ['Rashmi', 'DahalNuwakot', 33, 9803541509]

# %%
fruits = ["grapes","banana","orange","strawberry","peach","grapefruit"]
places = ["Kathmandu","Pokhara","Nuwaot"]
fruits.extend(places)
print(fruits)
# Out:
# ['grapes', 'banana', 'orange', 'strawberry', 'peach', 'grapefruit', 'Kathmandu', 'Pokhara', 'Nuwaot']

# %%
fruits = ['apple','banana','orange','strawberry','peach']
fruits.append('orange') # use append to add new index at the end of list
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'strawberry', 'peach', 'orange']

# %%
fruits = ["apple","banana","orange","strawberry","peach"]
fruits.insert(1,'orange')
print(fruits)
# Out:
# ['apple', 'orange', 'banana', 'orange', 'strawberry', 'peach']

# %%
places = ["Kathmandu","Pokhara","Nuwakot","pumdikot"]
places.remove("Nuwakot")
print(places)
# Out:
# ['Kathmandu', 'Pokhara', 'pumdikot']

# %%
places = ["Kathmandu","Pokhara","Nuwakot","Bhaktapur","Pokhara","Chitwan"]
places.pop(1)#Remove specified index
print(places)
# Out:
# ['Kathmandu', 'Nuwakot', 'Bhaktapur', 'Pokhara', 'Chitwan']

# %%
places = ["Kathmandu","Pokhara","Jhapa","Taplejung","Pachthar","Okhaldhunga","Bhaktapur"]
del places[0] #del also remove specified index
print(places)
# Out:
# ['Pokhara', 'Jhapa', 'Taplejung', 'Pachthar', 'Okhaldhunga', 'Bhaktapur']

# %%
places = ["Kathmandu","Pokhara","Jhapa","Taplejung"]
del places #This line delete whole list i.e places

# %%
places = ["Kathmandu","Pokhara","Jhapa"]
places.clear()#This clear method also delete whole list

# %%
places = ["Kathmandu","Pokhara","Jhapa"]
for x in places:
    print(x)
# Out:
# Kathmandu
# Pokhara
# Jhapa

# %%
places = ["kathmandu","Pokhara","Jhapa","Morang"]
for i in range(len(places)):
    print(places[i])
# Out:
# kathmandu
# Pokhara
# Jhapa
# Morang

# %%
fruits = ["watermelon","apple","pinapple","banana","orange","strawberry","peach"]
fruits.sort()
print(fruits)
fruits.reverse()
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'peach', 'pinapple', 'strawberry', 'watermelon']
# ['watermelon', 'strawberry', 'pinapple', 'peach', 'orange', 'banana', 'apple']

# %%
fruits = ["watermelon","apple","pinapple","banana","orange","strawberry","peach"]
fruits.sort(reverse=True)
print(fruits)
# Out:
# ['watermelon', 'strawberry', 'pinapple', 'peach', 'orange', 'banana', 'apple']

# %%
num = [20,44,36,76,23,90,12]
num.sort()
print(num)
# Out:
# [12, 20, 23, 36, 44, 76, 90]

# %%
num = [20,44,36,76,23,90,12]
num.sort(reverse=True)
print(num)
# Out:
# [90, 76, 44, 36, 23, 20, 12]

# %%
fruits = ["apple","banana","orange","strawberry","peach"]
fruit = fruits.copy()
print(fruit)
# Out:
# ['apple', 'banana', 'orange', 'strawberry', 'peach']

# %%
fruits = ["apple","banana","orange","strawberry","peach"]
thisfruit = list(fruits)
print(thisfruit)
# Out:
# ['apple', 'banana', 'orange', 'strawberry', 'peach']

# %%
fruits = ["apple","banana","orange","strawberry","peach"]
thisfruits = fruits[:]
print(thisfruits)
# Out:
# ['apple', 'banana', 'orange', 'strawberry', 'peach']

# %%
list1 = [1,2,3,4]
list2 = ['a','b','c','d','e','f','g','h']
list3 = list1 + list2 # joining list1 and list2
print(list3)
# Out:
# [1, 2, 3, 4, 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
list1 = ["Ram","Hari","shita","Geeta","Ram"]
list2 = ["Rimal","Dhital","Dahal","Khanal","Nepal"]
list1.extend(list2)
print(list1)
list1.append(list2)
print(list1)
# Out:
# ['Ram', 'Hari', 'shita', 'Geeta', 'Ram', 'Rimal', 'Dhital', 'Dahal', 'Khanal', 'Nepal']
# ['Ram', 'Hari', 'shita', 'Geeta', 'Ram', 'Rimal', 'Dhital', 'Dahal', 'Khanal', 'Nepal', ['Rimal', 'Dhital', 'Dahal', 'Khanal', 'Nepal']]

# %%
fruits = ["apple","banana","orange","strawberry","peach"]
print(fruits[0],fruits[-1])#printing first and last item
fruit = "mango"
fruits.append(fruit) #adding one element using append in list
print(fruits)
#print(fruits)
# Out:
# apple peach
# ['apple', 'banana', 'orange', 'strawberry', 'peach', 'mango']

# %%
fruits = ["apple","banana","orange","strawberry","peach"]
fruits.remove("apple")
length = len(fruits)
print(length)
print(fruits)
# Out:
# 4
# ['banana', 'orange', 'strawberry', 'peach']

# %%
num = [20,30,40,50,60,70,22]
sum = 0
for i in num:
    sum = i + sum
print(sum)
# Out:
# 292

# %%
num = [20,30,40,50,60,70,22]
print(num[::-1])
# Out:
# [22, 70, 60, 50, 40, 30, 20]

# %%
num = [20,30,40,50,60,70,22]
num2 = 1
for i in num:
    num2 = num2 * 2
    print(num2)
# Out:
# 2
# 4
# 8
# 16
# 32
# 64
# 128

# %%
list1 = [2,3,4,4,5,6,7]
list2 = [30,40,50,67,78]
list1.extend(list2)
print(list1)
# Out:
# [2, 3, 4, 4, 5, 6, 7, 30, 40, 50, 67, 78]
